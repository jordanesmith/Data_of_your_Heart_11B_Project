# %%
### tf-NNN-build conda env

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import wfdb
import os
import neurokit2 as nk #TODO look into this algorithm
from tqdm import tqdm
import scipy.io
from scipy.sparse import csc_matrix, spdiags
from scipy.sparse.linalg import spsolve

# %%
print('finding names of all test files ...')
all_files = []

for root, dirs, files in os.walk("F:\\DATA\\JSmith_SAFER_20220310\\raw_data"):
    for file in files:
        if(file.endswith(".dat")):
            all_files.append(os.path.join(root,file.split(".dat",2)[0]))
print('all files found :)')
# Out:
# finding names of all test files ...
# all files found :)

# %% [markdown]
# ## Find the recordings which have been manually reviewed
#
# ##### These lists are created in SAFERDataAnalysis.ipynb

# %%
import pickle
path_to_metadata_files = "F:\\DATA\\JSmith_SAFER_20220310\\metadata"

with open(os.path.join(path_to_metadata_files, "feas1"), "rb") as file:   
    meas_id_list_feas1 = pickle.load(file)
    
with open(os.path.join(path_to_metadata_files, "feas2"), "rb") as file:   
    meas_id_list_feas2 = pickle.load(file)

len(meas_id_list_feas1), len(meas_id_list_feas2), meas_id_list_feas1[0]
# Out:
# (4538, 1241, 2402)

# %%
feas1_filepaths_labelled = []
feas2_filepaths_labelled = []

for filepath in tqdm(all_files):
    
    if "Feas1" in filepath:
        if int(filepath.split("saferF1_",2)[1]) in meas_id_list_feas1:
            feas1_filepaths_labelled.append(filepath)
    
    elif "Feas2" in filepath:
        if int(filepath.split("saferF2_",2)[1]) in meas_id_list_feas1:
            feas2_filepaths_labelled.append(filepath)

len(feas1_filepaths_labelled), len(feas2_filepaths_labelled)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 185618/185618 [00:07<00:00, 23296.12it/s]
# (4524, 1089)

# %% [markdown]
# ## Filtering and preprocessing

# %%
from utils.preprocessing import baseline_als, butter_lowpass, butter_lowpass_filter
order = 6
fs = 30.0       

# # Filter requirements.
# order = 6
# fs = 30.0       # sample rate, Hz
# cutoff = 1.58  # desired cutoff frequency of the filter, Hz

# # Get the filter coefficients so we can check its frequency response.
# b, a = butter_lowpass(cutoff, fs, order)

# %% [markdown]
# ### Remove baseline wander

# %%
record = wfdb.rdrecord("F:\\DATA\\JSmith_SAFER_20220310\\raw_data\\Feas1\\ECGs\\002000\\saferF1_002958")
ecg_signal = record.p_signal.T[0]
signal_no_wander = ecg_signal - baseline_als(ecg_signal)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,6), tight_layout=True)

ax1.plot(ecg_signal)
ax2.plot(signal_no_wander)

ax1.set_title("Original signal")
ax2.set_title("Baseline Wander removed")

ax1.set_ylabel("signal strength")
ax2.set_ylabel("signal strength")

ax1.set_xlabel("time")
ax2.set_xlabel("time")
# Out:
# Text(0.5, 0, 'time')

# %% [markdown]
# ### LPF the signal

# %%
feas1_path_to_folder = "F:\\DATA\\JSmith_SAFER_20220310\\preprocessed_labelled_data\\Feas1"
feas1_already_processed_files = [files for root, dirs, files in os.walk(feas1_path_to_folder)][0]
feas1_processed_file_as_string = ''.join(item for item in feas1_already_processed_files)

fig, ( (ax1, ax2), (ax3, ax4), (ax5, ax6) ) = plt.subplots(3, 2, figsize=(15,10), tight_layout=True)
record = wfdb.rdrecord("F:\\DATA\\JSmith_SAFER_20220310\\raw_data\\Feas1\\ECGs\\002000\\saferF1_002958")
ecg_signal = record.p_signal.T[0]
signal_no_wander = ecg_signal - baseline_als(ecg_signal)

frequencies_to_try = np.logspace(-1,1,6)
for i, ax in enumerate([ax1, ax2, ax3, ax4, ax5, ax6]):
    freq = frequencies_to_try[i]
    signal_smoothed = butter_lowpass_filter(signal_no_wander, freq, fs, order)
    ax.plot(signal_no_wander[:1000], label="original")
    ax.plot(signal_smoothed[:1000], label="processed")
    ax.set_title(f"Lowpass filter cutoff frequence {np.round(freq,4)}") 
    ax.legend()
    ax.set_xlabel("time")
    ax.set_ylabel("signal strength")

# %% [markdown]
# 1.58 was chosen cutoff frequency

# %% [markdown]
# ## A typical preprocessed SAFER datapoint vs 2017 sample

# %%
test_file_SAFER = "F:\\DATA\\JSmith_SAFER_20220310\\preprocessed_labelled_data\\Feas1\\saferF1_040381"
original_file_SAFER = "F:\\DATA\\JSmith_SAFER_20220310\\raw_data\\Feas1\\ECGs\\040000\\saferF1_040381"
test_file_2017 = "D:\\OneDrive - University of Cambridge\\11B\\Project\\2_data\\physionet_datasets\\training2017\\A00002"

#preprocess
record = wfdb.rdrecord(original_file_SAFER)
ecg_signal = record.p_signal.T[0]
signal_no_wander = ecg_signal - baseline_als(ecg_signal)
signal_smoothed = butter_lowpass_filter(signal_no_wander, 1.58, fs, order)
signal_offset = signal_smoothed - np.min(signal_smoothed)
signal_squashed = 2 * signal_offset / np.max(signal_offset)
signal_normalised = signal_squashed - np.mean(signal_squashed)

# _ecg_signal = record.p_signal.T[0]
# _signal_no_wander = ecg_signal - baseline_als(ecg_signal)
# _signal_smoothed = butter_lowpass_filter(signal_no_wander, 1.58, fs, order)
# _signal_normalised = ( signal_smoothed -  np.mean(signal_smoothed) ) / np.abs(np.max(signal_smoothed) - np.min(signal_smoothed))

sample_2017 = wfdb.rdrecord(test_file_2017).p_signal.T[0]

fig, ( (ax1, ax2), (ax3, ax4), (ax5, ax6) ) = plt.subplots(3, 2, figsize=(15,10), tight_layout=True)

length_of_samples = np.logspace(3, np.log10(len(sample_2017)), 6)

for i,ax in enumerate([ax1,ax2,ax3,ax4,ax5,ax6]):
    length_to_plot = int(length_of_samples[i])
    ax.plot(signal_normalised[:length_to_plot], label="preprocessed")
    ax.plot(sample_2017[:length_to_plot], label="2017 data")
    ax.legend()
    ax.set_xlabel("time")
    ax.set_ylabel("signal strength")

# %% [markdown]
# ### Find all samples which are AF

# %%
af_df = pd.read_csv("F:\\DATA\\JSmith_SAFER_20220310\\raw_data\\Feas1\\files_with_af.csv", names=["filename"])
filenames_with_af = af_df.filename.tolist()

# %% [markdown]
# # Preprocess the data and save it

# %%
import shutil


# feas 1
feas1_path_to_folder = "F:\\DATA\\JSmith_SAFER_20220310\\preprocessed_labelled_data\\Feas1"
feas1_already_processed_files = [files for root, dirs, files in os.walk(feas1_path_to_folder)][0]
feas1_processed_file_as_string = ''.join(item for item in feas1_already_processed_files)

# for test_file in tqdm(feas1_filepaths_labelled):
for test_file in tqdm(filenames_with_af):
    
    # check not repeating process for already used file
    test_file_name = test_file.split("\\")[-1]    
    
    if test_file_name not in feas1_processed_file_as_string:
        #preprocess
        record = wfdb.rdrecord(test_file)
        ecg_signal = record.p_signal.T[0]
        plt.plot(ecg_signal)
        signal_no_wander = ecg_signal - baseline_als(ecg_signal)
        signal_smoothed = butter_lowpass_filter(signal_no_wander, 1.58, fs, order)
        signal_offset = signal_smoothed - np.min(signal_smoothed)
        signal_squashed = 2 * signal_offset / np.max(signal_offset)
        signal_normalised = signal_squashed - np.mean(signal_squashed)
        
#         plt.plot(signal_normalised[:8000], label="preprocessed")
#         plt.plot(sample_2017[:8000], label="2017")
#         plt.legend()
#         plt.show()
#         plt.clf()
                        
        #save this file
        filename = test_file.split("\\")[-1]
        npy_path = os.path.join(feas1_path_to_folder, filename)
        np.save(npy_path, signal_normalised)
        # #copy over .hea file
        # shutil.copyfile(test_file + ".hea", dat_path.replace(".dat", ".hea"))

        # record = wfdb.rdrecord(dat_path.split(".dat",2)[0])
        # ecg = record.p_signal.T[0]
        # ecg = np.load(npy_path+ ".npy")
        # plt.plot(ecg[:8000], label="open new")
        # plt.plot(sample_2017[:8000], label="2017")
        # plt.legend()
        # plt.show()
        # plt.clf()
        
        
        
#feas 2
# repeat above with feas2 not feas1
# Out:
#   File "C:\Users\Jordan\AppData\Local\Temp/ipykernel_14016/1888630107.py", line 10
#     ):
#     ^
# SyntaxError: invalid syntax

# %%
test_file_SAFER = "F:\\DATA\\JSmith_SAFER_20220310\\preprocessed_labelled_data\\Feas1\\saferF1_040381"
original_file_SAFER = "F:\\DATA\\JSmith_SAFER_20220310\\raw_data\\Feas1\\ECGs\\040000\\saferF1_040381"
test_file_2017 = "D:\\OneDrive - University of Cambridge\\11B\\Project\\2_data\\physionet_datasets\\training2017\\A00002"

end_indice = 100

record = wfdb.rdrecord(test_file_SAFER)

signal1 = record.p_signal.T[0]
signal2 = signal1 - baseline_als(signal1)
signal3 = ( signal1 -  np.mean(signal1) ) / np.std(signal1)
signal4 = butter_lowpass_filter(signal1, 0.7, 30)
signal5 = ( signal2 - np.mean(signal2) ) / np.std(signal2)
signal6 = butter_lowpass_filter(signal5, 0.7, 30)

fig, ( (ax1, ax2), (ax3, ax4), (ax5, ax6) ) = plt.subplots(3, 2, figsize=(27,10), tight_layout=True)
# fig.set_size_inches(18, 10)
ax1.plot(signal1[:end_indice])
ax1.set_title("Original signal")
ax2.plot(signal2[:end_indice])
ax2.set_title("Removed baseline wander")
ax3.plot(signal3[:end_indice])
ax3.set_title("Zero normalised, unit variance")
ax4.plot(signal4[:end_indice])
ax4.set_title("Low pass filtered")
ax5.plot(signal5[:end_indice])
ax5.set_title("Removed baseline wander then normalised")
ax6.plot(signal6[:end_indice])
ax6.set_title("Removed baseline wander, normalised then filtered")

ecg_2017 = scipy.io.loadmat(test_file_2017)['val'][0]
plt.plot(ecg_2017[:end_indice])
plt.plot(wfdb.rdrecord(original_file_SAFER).p_signal.T[0][:end_indice])
